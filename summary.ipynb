# %%
from nets.ssd import SSD300


if __name__ == "__main__":
    input_shape = [120, 160]
    num_classes = 2
    
    model = SSD300([input_shape[0], input_shape[1], 1], num_classes)
    model.summary()
    print(type(model))
    # print(dir(model))
    print(model.output)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 120, 160, 1)  0
# __________________________________________________________________________________________________
# DepthWiseConv2D_layer1 (Depthwi (None, 120, 160, 8)  80          input_2[0][0]
# __________________________________________________________________________________________________
# DepthWiseConv2D_layer2 (Depthwi (None, 60, 80, 8)    80          DepthWiseConv2D_layer1[0][0]
# __________________________________________________________________________________________________
# Conv2D_layer3 (Conv2D)          (None, 60, 80, 8)    72          DepthWiseConv2D_layer2[0][0]
# __________________________________________________________________________________________________
# ...
