# %%
import sys
sys.path.append("./keras/classification/")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  
from keras.preprocessing.image import ImageDataGenerator
from Models_verison2 import model_version2
from log_visualization_tool import visual_train
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
def cls_model_build(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/srp/RockSecissorsPaper_enlarge/", 
                    epoch=300, 
                    save_model_name = 'cls_model_0821.h5',
                    model_summary="True",
                    weights = None):
    
    model = model_version2()
    if weights is not None:
        model.load_weights(weights)
        
    test_data_path = data_path + "val"
    train_data_path = data_path + "train"
    validation_datagen = ImageDataGenerator(rescale=1. / 255)
    training_datagen = ImageDataGenerator(rescale=1. / 255,
                                          rotation_range=40, # 旋转范围
                                          width_shift_range=0.2, # 宽平移
                                          height_shift_range=0.2,# 高平移
                                          shear_range=0.2, # 剪切
                                          zoom_range=0.2, # 缩放
                                          horizontal_flip=True,
                                          fill_mode='nearest')
    
    training_generator = training_datagen.flow_from_directory(train_data_path,
                                                              target_size=(120, 160),
                                                              color_mode="grayscale",
                                                              class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(test_data_path,
                                                                  target_size=(120, 160),
                                                                  color_mode="grayscale",
                                                                  class_mode='categorical')
    

    # 使用 ReduceLROnPlateau 回调函数
    adam = Adam(lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6)
    early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
    model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    #======== 模型训练 =========
    history = model.fit(
        training_generator,
        epochs = epoch,
        validation_data = validation_generator,
        callbacks=[reduce_lr, early_stopping]
    )

    model.save(save_model_name) # model 保存

    return history

# %%
if __name__ == "__main__":
    history = cls_model_build(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/srp/RockSecissorsPaper_enlarge/", 
                              epoch=300, 
                              save_model_name = './../../output/keras/cls/model_0827_retrain.h5' )
    visual_train(history)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 120, 160, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 120, 160, 3)          30        ['input_1[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 120, 160, 3)          30        ['conv2d[0][0]']
#  eConv2D)
#
#  conv2d_1 (Conv2D)           (None, 120, 160, 16)         64        ['depthwise_conv2d[0][0]']
#
#  depthwise_conv2d_1 (Depthw  (None, 60, 80, 16)           160       ['conv2d_1[0][0]']
#  iseConv2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 80, 16)           448       ['conv2d[0][0]']
#
#  add (Add)                   (None, 60, 80, 16)           0         ['depthwise_conv2d_1[0][0]',
#                                                                      'conv2d_2[0][0]']
#
#  re_lu (ReLU)                (None, 60, 80, 16)           0         ['add[0][0]']
#
#  depthwise_conv2d_2 (Depthw  (None, 30, 40, 16)           160       ['re_lu[0][0]']
#  iseConv2D)
#
#  conv2d_3 (Conv2D)           (None, 30, 40, 32)           544       ['depthwise_conv2d_2[0][0]']
#
#  depthwise_conv2d_3 (Depthw  (None, 30, 40, 32)           320       ['conv2d_3[0][0]']
#  iseConv2D)
#
#  conv2d_4 (Conv2D)           (None, 30, 40, 32)           1056      ['depthwise_conv2d_3[0][0]']
#
#  depthwise_conv2d_4 (Depthw  (None, 15, 20, 32)           320       ['conv2d_4[0][0]']
#  iseConv2D)
#
#  conv2d_5 (Conv2D)           (None, 15, 20, 32)           9248      ['conv2d_3[0][0]']
#
#  batch_normalization (Batch  (None, 15, 20, 32)           128       ['depthwise_conv2d_4[0][0]']
#  Normalization)
#
#  batch_normalization_1 (Bat  (None, 15, 20, 32)           128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 15, 20, 32)           0         ['batch_normalization[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  re_lu_1 (ReLU)              (None, 15, 20, 32)           0         ['add_1[0][0]']
#
#  depthwise_conv2d_5 (Depthw  (None, 15, 20, 32)           320       ['re_lu_1[0][0]']
#  iseConv2D)
#
#  conv2d_6 (Conv2D)           (None, 15, 20, 32)           1056      ['depthwise_conv2d_5[0][0]']
#
#  depthwise_conv2d_6 (Depthw  (None, 8, 10, 32)            320       ['conv2d_6[0][0]']
#  iseConv2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 10, 32)            9248      ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 8, 10, 32)            128       ['depthwise_conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 8, 10, 32)            128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 8, 10, 32)            0         ['batch_normalization_2[0][0]'
#                                                                     , 'batch_normalization_3[0][0]
#                                                                     ']
#
#  re_lu_2 (ReLU)              (None, 8, 10, 32)            0         ['add_2[0][0]']
#
#  depthwise_conv2d_7 (Depthw  (None, 8, 10, 32)            320       ['re_lu_2[0][0]']
#  iseConv2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 10, 32)            1056      ['depthwise_conv2d_7[0][0]']
#
#  depthwise_conv2d_8 (Depthw  (None, 4, 5, 32)             320       ['conv2d_8[0][0]']
#  iseConv2D)
#
#  conv2d_9 (Conv2D)           (None, 4, 5, 32)             9248      ['re_lu_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 4, 5, 32)             128       ['depthwise_conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 4, 5, 32)             128       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 4, 5, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     , 'batch_normalization_5[0][0]
#                                                                     ']
#
#  re_lu_3 (ReLU)              (None, 4, 5, 32)             0         ['add_3[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 32)             0         ['re_lu_3[0][0]']
#  D)
#
#  flatten (Flatten)           (None, 128)                  0         ['max_pooling2d[0][0]']
#
#  dense (Dense)               (None, 64)                   8256      ['flatten[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64)                   256       ['dense[0][0]']
#  chNormalization)
#
#  dense_1 (Dense)             (None, 3)                    195       ['batch_normalization_6[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 43743 (170.87 KB)
# Trainable params: 43231 (168.87 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________
# Found 1221 images belonging to 3 classes.
# Found 57 images belonging to 3 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/300
# 39/39 [==============================] - 6s 100ms/step - loss: 0.7374 - accuracy: 0.4185 - val_loss: 0.6900 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 2/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.6455 - accuracy: 0.4685 - val_loss: 0.7133 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 3/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5972 - accuracy: 0.5119 - val_loss: 0.7214 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 4/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5719 - accuracy: 0.5397 - val_loss: 0.7070 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 5/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5528 - accuracy: 0.5536 - val_loss: 0.6774 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/300
# 39/39 [==============================] - 4s 91ms/step - loss: 0.5351 - accuracy: 0.5815 - val_loss: 0.6542 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/300
# 39/39 [==============================] - 4s 91ms/step - loss: 0.5250 - accuracy: 0.5987 - val_loss: 0.6597 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 8/300
# 39/39 [==============================] - 4s 91ms/step - loss: 0.5293 - accuracy: 0.5839 - val_loss: 0.6999 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5277 - accuracy: 0.5856 - val_loss: 0.6658 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 10/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5208 - accuracy: 0.6052 - val_loss: 0.9235 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 11/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5102 - accuracy: 0.6052 - val_loss: 0.7819 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 12/300
# 39/39 [==============================] - 3s 88ms/step - loss: 0.5071 - accuracy: 0.6102 - val_loss: 0.8480 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 13/300
# 39/39 [==============================] - 4s 89ms/step - loss: 0.5146 - accuracy: 0.6085 - val_loss: 1.5597 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch