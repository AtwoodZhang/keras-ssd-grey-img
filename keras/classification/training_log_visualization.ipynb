# %% [markdown]
# # Model_verison0

# %%
from Scissor_rock_paper import cls_model_v0
from log_visualization_tool import visual_train

history = cls_model_v0(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/srp/RockSecissorsPaper_enlarge/", 
                       epoch=100, 
                       save_model_name = 'class_08_test_model_2_less.h5' )
visual_train(history)
# Out:
# Found 573 images belonging to 3 classes.
# Found 57 images belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 118, 158, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 59, 79, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 57, 77, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 38, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 26, 36, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 18, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 16, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 8, 32)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 3, 6, 64)          18496
#
#  conv2d_5 (Conv2D)           (None, 1, 4, 32)          18464
#
#  flatten (Flatten)           (None, 128)               0
#
# ...
