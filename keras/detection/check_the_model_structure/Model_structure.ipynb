# %%
import tensorflow as tf

def print_tflite_model_summary(model_path):
    # 创建 TFLite 解释器
    interpreter = tf.lite.Interpreter(model_path=model_path)

    # 分配张量内存
    interpreter.allocate_tensors()

    # 获取输入和输出张量的详细信息
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # 打印模型的输入信息
    print("Input Shape:")
    for input_tensor in input_details:
        print(f"  {input_tensor['name']}: {input_tensor['shape']}")

    # 打印模型的输出信息
    print("\nOutput Shape:")
    for output_tensor in output_details:
        print(f"  {output_tensor['name']}: {output_tensor['shape']}")

    # 打印完整的网络结构
    print("\nNetwork Structure:")
    for i, layer in enumerate(interpreter.get_tensor_details()):
        print(f"Layer {i} - {layer['name']} - Shape: {layer['shape']}")

# 用法示例
# 定义 TFLite 模型文件路径
tflite_model_path = '/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/Quantization/quantized_model_1214.tflite'
print_tflite_model_summary(tflite_model_path)
# Out:
# Input Shape:
#   serving_default_input_1:0: [  1 120 160   1]
#
# Output Shape:
#   StatefulPartitionedCall:0: [   1 1242    7]
#
# Network Structure:
# Layer 0 - serving_default_input_1:0 - Shape: [  1 120 160   1]
# Layer 1 - model/mbox_loc_final/strided_slice/stack - Shape: [1]
# Layer 2 - model/mbox_loc_final/strided_slice/stack_1 - Shape: [1]
# Layer 3 - model/reshape_8/Reshape/shape/1 - Shape: []
# Layer 4 - model/reshape/Reshape/shape/2 - Shape: []
# Layer 5 - model/reshape_6/Reshape/shape/1 - Shape: []
# Layer 6 - model/reshape_4/Reshape/shape/1 - Shape: []
# Layer 7 - model/reshape_2/Reshape/shape/1 - Shape: []
# Layer 8 - model/reshape/Reshape/shape/1 - Shape: []
# Layer 9 - model/mbox_loc_final/Reshape/shape/2 - Shape: []
# Layer 10 - model/Conv2D_loc_DD5_2/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 11 - model/Conv2D_loc_DD5_2/Conv2D - Shape: [24  1  1 64]
# Layer 12 - model/DepthwiseConv2D_loc_DD5_1/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 13 - model/DepthwiseConv2D_loc_DD5_1/depthwise - Shape: [ 1  3  3 64]
# Layer 14 - model/Conv2D_loc_DD4_2/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 15 - model/Conv2D_loc_DD4_2/Conv2D - Shape: [24  1  1 64]
# Layer 16 - model/DepthwiseConv2D_loc_DD4_1/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 17 - model/DepthwiseConv2D_loc_DD4_1/depthwise - Shape: [ 1  3  3 64]
# Layer 18 - model/Conv2D_loc_DD3_2/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 19 - model/Conv2D_loc_DD3_2/Conv2D - Shape: [24  1  1 80]
# Layer 20 - model/DepthwiseConv2D_loc_DD3_1/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 21 - model/DepthwiseConv2D_loc_DD3_1/depthwise - Shape: [ 1  3  3 80]
# Layer 22 - model/Conv2D_loc_DD2_2/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 23 - model/Conv2D_loc_DD2_2/Conv2D - Shape: [24  1  1 80]
# Layer 24 - model/DepthwiseConv2D_loc_DD2_1/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 25 - model/DepthwiseConv2D_loc_DD2_1/depthwise - Shape: [ 1  3  3 80]
# Layer 26 - model/Conv2D_loc_DD1_2/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 27 - model/Conv2D_loc_DD1_2/Conv2D - Shape: [ 8  1  1 64]
# Layer 28 - model/DepthwiseConv2D_loc_DD1_1/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 29 - model/DepthwiseConv2D_loc_DD1_1/depthwise - Shape: [ 1  3  3 64]
# Layer 30 - model/Conv2D_conf_DD1_2/BiasAdd/ReadVariableOp - Shape: [6]
# Layer 31 - model/Conv2D_conf_DD1_2/Conv2D - Shape: [ 6  1  1 64]
# Layer 32 - model/DepthwiseConv2D_conf_DD1_1/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 33 - model/DepthwiseConv2D_conf_DD1_1/depthwise - Shape: [ 1  3  3 64]
# Layer 34 - model/Conv2D_conf_DD2_2/BiasAdd/ReadVariableOp - Shape: [18]
# Layer 35 - model/Conv2D_conf_DD2_2/Conv2D - Shape: [18  1  1 80]
# Layer 36 - model/DepthwiseConv2D_conf_DD2_1/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 37 - model/DepthwiseConv2D_conf_DD2_1/depthwise - Shape: [ 1  3  3 80]
# Layer 38 - model/Conv2D_conf_DD3_2/BiasAdd/ReadVariableOp - Shape: [18]
# Layer 39 - model/Conv2D_conf_DD3_2/Conv2D - Shape: [18  1  1 80]
# Layer 40 - model/DepthwiseConv2D_conf_DD3_1/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 41 - model/DepthwiseConv2D_conf_DD3_1/depthwise - Shape: [ 1  3  3 80]
# Layer 42 - model/Conv2D_conf_DD4_2/BiasAdd/ReadVariableOp - Shape: [18]
# Layer 43 - model/Conv2D_conf_DD4_2/Conv2D - Shape: [18  1  1 64]
# Layer 44 - model/DepthwiseConv2D_conf_DD4_1/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 45 - model/DepthwiseConv2D_conf_DD4_1/depthwise - Shape: [ 1  3  3 64]
# Layer 46 - model/Conv2D_conf_DD5_2/BiasAdd/ReadVariableOp - Shape: [18]
# Layer 47 - model/Conv2D_conf_DD5_2/Conv2D - Shape: [18  1  1 64]
# Layer 48 - model/DepthwiseConv2D_conf_DD5_1/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 49 - model/DepthwiseConv2D_conf_DD5_1/depthwise - Shape: [ 1  3  3 64]
# Layer 50 - model/Conv2D_layer24/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 51 - model/Conv2D_layer24/Conv2D - Shape: [64  1  1 64]
# Layer 52 - model/DepthWiseConv2D_layer23/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 53 - model/DepthWiseConv2D_layer23/depthwise - Shape: [ 1  3  3 64]
# Layer 54 - model/Conv2D_layer22/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 55 - model/Conv2D_layer22/Conv2D - Shape: [64  1  1 80]
# Layer 56 - model/DepthWiseConv2D_layer21/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 57 - model/DepthWiseConv2D_layer21/depthwise - Shape: [ 1  3  3 80]
# Layer 58 - model/Conv2D_layer20/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 59 - model/Conv2D_layer20/Conv2D - Shape: [80  1  1 80]
# Layer 60 - model/DepthWiseConv2D_layer19/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 61 - model/DepthWiseConv2D_layer19/depthwise - Shape: [ 1  3  3 80]
# Layer 62 - model/Conv2D_layer18/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 63 - model/Conv2D_layer18/Conv2D - Shape: [80  1  1 80]
# Layer 64 - model/DepthWiseConv2D_layer17/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 65 - model/DepthWiseConv2D_layer17/depthwise - Shape: [ 1  3  3 80]
# Layer 66 - model/Conv2D_layer16/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 67 - model/Conv2D_layer16/Conv2D - Shape: [80  1  1 40]
# Layer 68 - model/block_8_conv_pw/BiasAdd/ReadVariableOp - Shape: [40]
# Layer 69 - model/block_8_conv_pw/Conv2D - Shape: [40  1  1 80]
# Layer 70 - model/block_8_conv_dw/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 71 - model/block_8_conv_dw/depthwise - Shape: [ 1  3  3 80]
# Layer 72 - model/block_7_conv_pw/BiasAdd/ReadVariableOp - Shape: [40]
# Layer 73 - model/block_7_conv_pw/Conv2D - Shape: [40  1  1 80]
# Layer 74 - model/block_7_conv_dw/BiasAdd/ReadVariableOp - Shape: [80]
# Layer 75 - model/block_7_conv_dw/depthwise - Shape: [ 1  3  3 80]
# Layer 76 - model/Conv2D_layer15/BiasAdd/ReadVariableOp - Shape: [40]
# Layer 77 - model/Conv2D_layer15/Conv2D - Shape: [40  1  1 64]
# Layer 78 - model/DepthWiseConv2D_layer14/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 79 - model/DepthWiseConv2D_layer14/depthwise - Shape: [ 1  3  3 64]
# Layer 80 - model/Conv2D_layer13/BiasAdd/ReadVariableOp - Shape: [64]
# Layer 81 - model/Conv2D_layer13/Conv2D - Shape: [64  1  1 48]
# Layer 82 - model/DepthWiseConv2D_layer12/BiasAdd/ReadVariableOp - Shape: [48]
# Layer 83 - model/DepthWiseConv2D_layer12/depthwise - Shape: [ 1  3  3 48]
# Layer 84 - model/Conv2D_layer11/BiasAdd/ReadVariableOp - Shape: [48]
# Layer 85 - model/Conv2D_layer11/Conv2D - Shape: [48  1  1 24]
# Layer 86 - model/block_6_conv_pw/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 87 - model/block_6_conv_pw/Conv2D - Shape: [24  1  1 48]
# Layer 88 - model/block_6_conv_dw/BiasAdd/ReadVariableOp - Shape: [48]
# Layer 89 - model/block_6_conv_dw/depthwise - Shape: [ 1  3  3 48]
# Layer 90 - model/block_5_conv_pw/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 91 - model/block_5_conv_pw/Conv2D - Shape: [24  1  1 48]
# Layer 92 - model/block_5_conv_dw/BiasAdd/ReadVariableOp - Shape: [48]
# Layer 93 - model/block_5_conv_dw/depthwise - Shape: [ 1  3  3 48]
# Layer 94 - model/block_4_conv_pw/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 95 - model/block_4_conv_pw/Conv2D - Shape: [24  1  1 48]
# Layer 96 - model/block_4_conv_dw/BiasAdd/ReadVariableOp - Shape: [48]
# Layer 97 - model/block_4_conv_dw/depthwise - Shape: [ 1  3  3 48]
# Layer 98 - model/Conv2D_layer10/BiasAdd/ReadVariableOp - Shape: [24]
# Layer 99 - model/Conv2D_layer10/Conv2D - Shape: [24  1  1 32]
# Layer 100 - model/DepthWiseConv2D_layer9/BiasAdd/ReadVariableOp - Shape: [32]
# Layer 101 - model/DepthWiseConv2D_layer9/depthwise - Shape: [ 1  3  3 32]
# Layer 102 - model/Conv2D_layer8/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 103 - model/Conv2D_layer8/Conv2D - Shape: [16  1  1 16]
# Layer 104 - model/DepthWiseConv2D_layer7/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 105 - model/DepthWiseConv2D_layer7/depthwise - Shape: [ 1  3  3 16]
# Layer 106 - model/Conv2D_layer6/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 107 - model/Conv2D_layer6/Conv2D - Shape: [16  1  1  8]
# Layer 108 - model/block_3_conv_pw/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 109 - model/block_3_conv_pw/Conv2D - Shape: [ 8  1  1 16]
# Layer 110 - model/block_3_conv_dw/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 111 - model/block_3_conv_dw/depthwise - Shape: [ 1  3  3 16]
# Layer 112 - model/block_2_conv_pw/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 113 - model/block_2_conv_pw/Conv2D - Shape: [ 8  1  1 16]
# Layer 114 - model/block_2_conv_dw/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 115 - model/block_2_conv_dw/depthwise - Shape: [ 1  3  3 16]
# Layer 116 - model/block_1_conv_pw/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 117 - model/block_1_conv_pw/Conv2D - Shape: [ 8  1  1 16]
# Layer 118 - model/block_1_conv_dw/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 119 - model/block_1_conv_dw/depthwise - Shape: [ 1  3  3 16]
# Layer 120 - model/Conv2D_layer5/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 121 - model/Conv2D_layer5/Conv2D - Shape: [ 8  1  1 16]
# Layer 122 - model/DepthWiseConv2D_layer4/BiasAdd/ReadVariableOp - Shape: [16]
# Layer 123 - model/DepthWiseConv2D_layer4/depthwise - Shape: [ 1  3  3 16]
# Layer 124 - model/Conv2D_layer3/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 125 - model/Conv2D_layer3/Conv2D - Shape: [8 1 1 8]
# Layer 126 - model/DepthWiseConv2D_layer2/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 127 - model/DepthWiseConv2D_layer2/depthwise - Shape: [1 3 3 8]
# Layer 128 - model/DepthWiseConv2D_layer1/BiasAdd/ReadVariableOp - Shape: [8]
# Layer 129 - model/DepthWiseConv2D_layer1/depthwise - Shape: [1 3 3 8]
# Layer 130 - model/re_lu/Relu6;model/DepthWiseConv2D_layer1/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/DepthWiseConv2D_layer1/depthwise;model/DepthWiseConv2D_layer1/BiasAdd/ReadVariableOp - Shape: [  1 120 160   8]
# Layer 131 - model/re_lu_1/Relu6;model/DepthWiseConv2D_layer2/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/DepthWiseConv2D_layer2/depthwise;model/DepthWiseConv2D_layer2/BiasAdd/ReadVariableOp - Shape: [ 1 60 80  8]
# Layer 132 - model/re_lu_2/Relu6;model/Conv2D_layer3/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/Conv2D_layer3/Conv2D;model/Conv2D_layer3/BiasAdd/ReadVariableOp - Shape: [ 1 60 80  8]
# Layer 133 - model/re_lu_3/Relu6;model/DepthWiseConv2D_layer4/BiasAdd;model/Conv2D_layer8/Conv2D;model/DepthWiseConv2D_layer4/depthwise;model/DepthWiseConv2D_layer4/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 134 - model/re_lu_4/Relu6;model/Conv2D_layer5/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/Conv2D_layer5/Conv2D;model/Conv2D_layer5/BiasAdd/ReadVariableOp - Shape: [ 1 30 40  8]
# Layer 135 - model/re_lu_5/Relu6;model/block_1_conv_dw/BiasAdd;model/Conv2D_layer8/Conv2D;model/block_1_conv_dw/depthwise;model/block_1_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 136 - model/block_1_conv_pw/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/block_1_conv_pw/Conv2D;model/block_1_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1 30 40  8]
# Layer 137 - model/add/add - Shape: [ 1 30 40  8]
# Layer 138 - model/re_lu_6/Relu6;model/block_2_conv_dw/BiasAdd;model/Conv2D_layer8/Conv2D;model/block_2_conv_dw/depthwise;model/block_2_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 139 - model/block_2_conv_pw/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/block_2_conv_pw/Conv2D;model/block_2_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1 30 40  8]
# Layer 140 - model/add_1/add - Shape: [ 1 30 40  8]
# Layer 141 - model/re_lu_7/Relu6;model/block_3_conv_dw/BiasAdd;model/Conv2D_layer8/Conv2D;model/block_3_conv_dw/depthwise;model/block_3_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 142 - model/block_3_conv_pw/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/block_3_conv_pw/Conv2D;model/block_3_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1 30 40  8]
# Layer 143 - model/add_2/add - Shape: [ 1 30 40  8]
# Layer 144 - model/re_lu_8/Relu6;model/Conv2D_layer6/BiasAdd;model/Conv2D_layer8/Conv2D;model/Conv2D_layer6/Conv2D;model/Conv2D_layer6/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 145 - model/re_lu_9/Relu6;model/DepthWiseConv2D_layer7/BiasAdd;model/Conv2D_layer8/Conv2D;model/DepthWiseConv2D_layer7/depthwise;model/DepthWiseConv2D_layer7/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 146 - model/re_lu_10/Relu6;model/Conv2D_layer8/BiasAdd;model/Conv2D_layer8/Conv2D;model/Conv2D_layer8/BiasAdd/ReadVariableOp - Shape: [ 1 30 40 16]
# Layer 147 - model/re_lu_11/Relu6;model/DepthWiseConv2D_layer9/BiasAdd;model/DepthWiseConv2D_layer9/depthwise;model/DepthWiseConv2D_layer9/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 32]
# Layer 148 - model/re_lu_12/Relu6;model/Conv2D_layer10/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/Conv2D_layer10/Conv2D;model/Conv2D_layer10/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 24]
# Layer 149 - model/re_lu_13/Relu6;model/block_4_conv_dw/BiasAdd;model/DepthWiseConv2D_layer12/depthwise;model/block_4_conv_dw/depthwise;model/block_4_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 48]
# Layer 150 - model/block_4_conv_pw/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/block_4_conv_pw/Conv2D;model/block_4_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 24]
# Layer 151 - model/add_3/add - Shape: [ 1 15 20 24]
# Layer 152 - model/re_lu_14/Relu6;model/block_5_conv_dw/BiasAdd;model/DepthWiseConv2D_layer12/depthwise;model/block_5_conv_dw/depthwise;model/block_5_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 48]
# Layer 153 - model/block_5_conv_pw/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/block_5_conv_pw/Conv2D;model/block_5_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 24]
# Layer 154 - model/add_4/add - Shape: [ 1 15 20 24]
# Layer 155 - model/re_lu_15/Relu6;model/block_6_conv_dw/BiasAdd;model/DepthWiseConv2D_layer12/depthwise;model/block_6_conv_dw/depthwise;model/block_6_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 48]
# Layer 156 - model/block_6_conv_pw/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/block_6_conv_pw/Conv2D;model/block_6_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 24]
# Layer 157 - model/add_5/add - Shape: [ 1 15 20 24]
# Layer 158 - model/re_lu_16/Relu6;model/Conv2D_layer11/BiasAdd;model/DepthWiseConv2D_layer12/depthwise;model/Conv2D_layer11/Conv2D;model/Conv2D_layer11/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 48]
# Layer 159 - model/re_lu_17/Relu6;model/DepthWiseConv2D_layer12/BiasAdd;model/DepthWiseConv2D_layer12/depthwise;model/DepthWiseConv2D_layer12/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 48]
# Layer 160 - model/re_lu_18/Relu6;model/Conv2D_layer13/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/Conv2D_layer13/Conv2D;model/Conv2D_layer13/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 64]
# Layer 161 - model/re_lu_19/Relu6;model/DepthWiseConv2D_layer14/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthWiseConv2D_layer14/depthwise;model/DepthWiseConv2D_layer14/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 64]
# Layer 162 - model/re_lu_20/Relu6;model/Conv2D_layer15/BiasAdd;model/block_8_conv_pw/Conv2D;model/Conv2D_layer15/Conv2D;model/Conv2D_layer15/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 40]
# Layer 163 - model/re_lu_21/Relu6;model/block_7_conv_dw/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/block_7_conv_dw/depthwise;model/block_7_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 164 - model/block_7_conv_pw/BiasAdd;model/block_8_conv_pw/Conv2D;model/block_7_conv_pw/Conv2D;model/block_7_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 40]
# Layer 165 - model/add_6/add - Shape: [ 1  8 10 40]
# Layer 166 - model/re_lu_22/Relu6;model/block_8_conv_dw/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/block_8_conv_dw/depthwise;model/block_8_conv_dw/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 167 - model/block_8_conv_pw/BiasAdd;model/block_8_conv_pw/Conv2D;model/block_8_conv_pw/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 40]
# Layer 168 - model/add_7/add - Shape: [ 1  8 10 40]
# Layer 169 - model/re_lu_23/Relu6;model/Conv2D_layer16/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/Conv2D_layer16/Conv2D;model/Conv2D_layer16/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 170 - model/re_lu_24/Relu6;model/DepthWiseConv2D_layer17/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthWiseConv2D_layer17/depthwise;model/DepthWiseConv2D_layer17/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 171 - model/re_lu_25/Relu6;model/Conv2D_layer18/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/Conv2D_layer18/Conv2D;model/Conv2D_layer18/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 172 - model/re_lu_26/Relu6;model/DepthWiseConv2D_layer19/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthWiseConv2D_layer19/depthwise;model/DepthWiseConv2D_layer19/BiasAdd/ReadVariableOp - Shape: [ 1  4  5 80]
# Layer 173 - model/re_lu_27/Relu6;model/Conv2D_layer20/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/Conv2D_layer20/Conv2D;model/Conv2D_layer20/BiasAdd/ReadVariableOp - Shape: [ 1  4  5 80]
# Layer 174 - model/re_lu_28/Relu6;model/DepthWiseConv2D_layer21/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthWiseConv2D_layer21/depthwise;model/DepthWiseConv2D_layer21/BiasAdd/ReadVariableOp - Shape: [ 1  2  3 80]
# Layer 175 - model/re_lu_29/Relu6;model/Conv2D_layer22/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/Conv2D_layer22/Conv2D;model/Conv2D_layer22/BiasAdd/ReadVariableOp - Shape: [ 1  2  3 64]
# Layer 176 - model/re_lu_30/Relu6;model/DepthWiseConv2D_layer23/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthWiseConv2D_layer23/depthwise;model/DepthWiseConv2D_layer23/BiasAdd/ReadVariableOp - Shape: [ 1  1  1 64]
# Layer 177 - model/re_lu_31/Relu6;model/Conv2D_layer24/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/Conv2D_layer24/Conv2D;model/Conv2D_layer24/BiasAdd/ReadVariableOp - Shape: [ 1  1  1 64]
# Layer 178 - model/re_lu_40/Relu6;model/DepthwiseConv2D_conf_DD5_1/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthwiseConv2D_conf_DD5_1/depthwise;model/DepthwiseConv2D_conf_DD5_1/BiasAdd/ReadVariableOp - Shape: [ 1  1  1 64]
# Layer 179 - model/Conv2D_conf_DD5_2/BiasAdd;model/Conv2D_conf_DD2_2/Conv2D;model/Conv2D_conf_DD5_2/Conv2D;model/Conv2D_conf_DD5_2/BiasAdd/ReadVariableOp - Shape: [ 1  1  1 18]
# Layer 180 - model/reshape_8/Shape - Shape: [4]
# Layer 181 - model/reshape_8/strided_slice - Shape: []
# Layer 182 - model/reshape_8/Reshape/shape - Shape: [3]
# Layer 183 - model/reshape_8/Reshape - Shape: [1 6 3]
# Layer 184 - model/re_lu_38/Relu6;model/DepthwiseConv2D_conf_DD4_1/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthwiseConv2D_conf_DD4_1/depthwise;model/DepthwiseConv2D_conf_DD4_1/BiasAdd/ReadVariableOp - Shape: [ 1  2  3 64]
# Layer 185 - model/Conv2D_conf_DD4_2/BiasAdd;model/Conv2D_conf_DD2_2/Conv2D;model/Conv2D_conf_DD4_2/Conv2D;model/Conv2D_conf_DD4_2/BiasAdd/ReadVariableOp - Shape: [ 1  2  3 18]
# Layer 186 - model/reshape_6/Shape - Shape: [4]
# Layer 187 - model/reshape_6/strided_slice - Shape: []
# Layer 188 - model/reshape_6/Reshape/shape - Shape: [3]
# Layer 189 - model/reshape_6/Reshape - Shape: [ 1 36  3]
# Layer 190 - model/re_lu_36/Relu6;model/DepthwiseConv2D_conf_DD3_1/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthwiseConv2D_conf_DD3_1/depthwise;model/DepthwiseConv2D_conf_DD3_1/BiasAdd/ReadVariableOp - Shape: [ 1  4  5 80]
# Layer 191 - model/Conv2D_conf_DD3_2/BiasAdd;model/Conv2D_conf_DD2_2/Conv2D;model/Conv2D_conf_DD3_2/Conv2D;model/Conv2D_conf_DD3_2/BiasAdd/ReadVariableOp - Shape: [ 1  4  5 18]
# Layer 192 - model/reshape_4/Shape - Shape: [4]
# Layer 193 - model/reshape_4/strided_slice - Shape: []
# Layer 194 - model/reshape_4/Reshape/shape - Shape: [3]
# Layer 195 - model/reshape_4/Reshape - Shape: [  1 120   3]
# Layer 196 - model/re_lu_34/Relu6;model/DepthwiseConv2D_conf_DD2_1/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthwiseConv2D_conf_DD2_1/depthwise;model/DepthwiseConv2D_conf_DD2_1/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 197 - model/Conv2D_conf_DD2_2/BiasAdd;model/Conv2D_conf_DD2_2/Conv2D;model/Conv2D_conf_DD2_2/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 18]
# Layer 198 - model/reshape_2/Shape - Shape: [4]
# Layer 199 - model/reshape_2/strided_slice - Shape: []
# Layer 200 - model/reshape_2/Reshape/shape - Shape: [3]
# Layer 201 - model/reshape_2/Reshape - Shape: [  1 480   3]
# Layer 202 - model/re_lu_32/Relu6;model/DepthwiseConv2D_conf_DD1_1/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthwiseConv2D_conf_DD1_1/depthwise;model/DepthwiseConv2D_conf_DD1_1/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 64]
# Layer 203 - model/Conv2D_conf_DD1_2/BiasAdd;model/Conv2D_conf_DD1_2/Conv2D;model/Conv2D_conf_DD1_2/BiasAdd/ReadVariableOp - Shape: [ 1 15 20  6]
# Layer 204 - model/reshape/Shape - Shape: [4]
# Layer 205 - model/reshape/strided_slice - Shape: []
# Layer 206 - model/reshape/Reshape/shape - Shape: [3]
# Layer 207 - model/reshape/Reshape - Shape: [  1 600   3]
# Layer 208 - model/mbox_conf/concat - Shape: [   1 1242    3]
# Layer 209 - model/cls_conf_final/Softmax - Shape: [   1 1242    3]
# Layer 210 - model/cls_conf_final/Softmax1 - Shape: [   1 1242    3]
# Layer 211 - model/re_lu_33/Relu6;model/DepthwiseConv2D_loc_DD1_1/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthwiseConv2D_loc_DD1_1/depthwise;model/DepthwiseConv2D_loc_DD1_1/BiasAdd/ReadVariableOp - Shape: [ 1 15 20 64]
# Layer 212 - model/Conv2D_loc_DD1_2/BiasAdd;model/Conv2D_loc_DD1_2/Conv2D;model/Conv2D_loc_DD1_2/BiasAdd/ReadVariableOp - Shape: [ 1 15 20  8]
# Layer 213 - model/reshape_1/Shape - Shape: [4]
# Layer 214 - model/reshape_1/strided_slice - Shape: []
# Layer 215 - model/reshape_1/Reshape/shape - Shape: [3]
# Layer 216 - model/reshape_1/Reshape - Shape: [  1 600   4]
# Layer 217 - model/re_lu_35/Relu6;model/DepthwiseConv2D_loc_DD2_1/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthwiseConv2D_loc_DD2_1/depthwise;model/DepthwiseConv2D_loc_DD2_1/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 80]
# Layer 218 - model/Conv2D_loc_DD2_2/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/Conv2D_loc_DD2_2/Conv2D;model/Conv2D_loc_DD2_2/BiasAdd/ReadVariableOp - Shape: [ 1  8 10 24]
# Layer 219 - model/reshape_3/Shape - Shape: [4]
# Layer 220 - model/reshape_3/strided_slice - Shape: []
# Layer 221 - model/reshape_3/Reshape/shape - Shape: [3]
# Layer 222 - model/reshape_3/Reshape - Shape: [  1 480   4]
# Layer 223 - model/re_lu_37/Relu6;model/DepthwiseConv2D_loc_DD3_1/BiasAdd;model/DepthwiseConv2D_loc_DD3_1/depthwise;model/DepthwiseConv2D_loc_DD3_1/BiasAdd/ReadVariableOp - Shape: [ 1  4  5 80]
# Layer 224 - model/Conv2D_loc_DD3_2/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/Conv2D_loc_DD3_2/Conv2D;model/Conv2D_loc_DD3_2/BiasAdd/ReadVariableOp - Shape: [ 1  4  5 24]
# Layer 225 - model/reshape_5/Shape - Shape: [4]
# Layer 226 - model/reshape_5/strided_slice - Shape: []
# Layer 227 - model/reshape_5/Reshape/shape - Shape: [3]
# Layer 228 - model/reshape_5/Reshape - Shape: [  1 120   4]
# Layer 229 - model/re_lu_39/Relu6;model/DepthwiseConv2D_loc_DD4_1/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthwiseConv2D_loc_DD4_1/depthwise;model/DepthwiseConv2D_loc_DD4_1/BiasAdd/ReadVariableOp - Shape: [ 1  2  3 64]
# Layer 230 - model/Conv2D_loc_DD4_2/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/Conv2D_loc_DD4_2/Conv2D;model/Conv2D_loc_DD4_2/BiasAdd/ReadVariableOp - Shape: [ 1  2  3 24]
# Layer 231 - model/reshape_7/Shape - Shape: [4]
# Layer 232 - model/reshape_7/strided_slice - Shape: []
# Layer 233 - model/reshape_7/Reshape/shape - Shape: [3]
# Layer 234 - model/reshape_7/Reshape - Shape: [ 1 36  4]
# Layer 235 - model/re_lu_41/Relu6;model/DepthwiseConv2D_loc_DD5_1/BiasAdd;model/DepthwiseConv2D_loc_DD5_1/depthwise;model/DepthwiseConv2D_loc_DD5_1/BiasAdd/ReadVariableOp - Shape: [ 1  1  1 64]
# Layer 236 - model/Conv2D_loc_DD5_2/BiasAdd;model/Conv2D_loc_DD5_2/Conv2D;model/Conv2D_loc_DD5_2/BiasAdd/ReadVariableOp - Shape: [ 1  1  1 24]
# Layer 237 - model/reshape_9/Shape - Shape: [4]
# Layer 238 - model/reshape_9/strided_slice - Shape: []
# Layer 239 - model/reshape_9/Reshape/shape - Shape: [3]
# Layer 240 - model/reshape_9/Reshape - Shape: [1 6 4]
# Layer 241 - model/mbox_loc/concat - Shape: [   1 1242    4]
# Layer 242 - StatefulPartitionedCall:0 - Shape: [   1 1242    7]
# Layer 243 -  - Shape: [ 1  8 10 64]

# %%
from keras.models import load_model

# 加载模型
h5_model_path = '/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_two_objects/output/20231206/20231213_good_detection_test_callback.h5'

# 注册自定义对象
custom_objects = {'compute_loss': None}

# 加载模型时传递 custom_objects 参数
loaded_model = load_model(h5_model_path, custom_objects=custom_objects)

# 打印模型结构
loaded_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 120, 160, 1)]        0         []
#
#  DepthWiseConv2D_layer1 (De  (None, 120, 160, 8)          80        ['input_1[0][0]']
#  pthwiseConv2D)
#
#  re_lu (ReLU)                (None, 120, 160, 8)          0         ['DepthWiseConv2D_layer1[0][0]
#                                                                     ']
#
#  DepthWiseConv2D_layer2 (De  (None, 60, 80, 8)            80        ['re_lu[0][0]']
#  pthwiseConv2D)
#
#  re_lu_1 (ReLU)              (None, 60, 80, 8)            0         ['DepthWiseConv2D_layer2[0][0]
#                                                                     ']
#
#  Conv2D_layer3 (Conv2D)      (None, 60, 80, 8)            72        ['re_lu_1[0][0]']
#
#  re_lu_2 (ReLU)              (None, 60, 80, 8)            0         ['Conv2D_layer3[0][0]']
#
#  DepthWiseConv2D_layer4 (De  (None, 30, 40, 16)           160       ['re_lu_2[0][0]']
#  pthwiseConv2D)
#
#  re_lu_3 (ReLU)              (None, 30, 40, 16)           0         ['DepthWiseConv2D_layer4[0][0]
#                                                                     ']
#
#  Conv2D_layer5 (Conv2D)      (None, 30, 40, 8)            136       ['re_lu_3[0][0]']
#
#  re_lu_4 (ReLU)              (None, 30, 40, 8)            0         ['Conv2D_layer5[0][0]']
#
#  block_1_conv_dw (Depthwise  (None, 30, 40, 16)           160       ['re_lu_4[0][0]']
#  Conv2D)
#
#  re_lu_5 (ReLU)              (None, 30, 40, 16)           0         ['block_1_conv_dw[0][0]']
#
#  block_1_conv_pw (Conv2D)    (None, 30, 40, 8)            136       ['re_lu_5[0][0]']
#
#  add (Add)                   (None, 30, 40, 8)            0         ['re_lu_4[0][0]',
#                                                                      'block_1_conv_pw[0][0]']
#
#  block_2_conv_dw (Depthwise  (None, 30, 40, 16)           160       ['add[0][0]']
#  Conv2D)
#
#  re_lu_6 (ReLU)              (None, 30, 40, 16)           0         ['block_2_conv_dw[0][0]']
#
#  block_2_conv_pw (Conv2D)    (None, 30, 40, 8)            136       ['re_lu_6[0][0]']
#
#  add_1 (Add)                 (None, 30, 40, 8)            0         ['add[0][0]',
#                                                                      'block_2_conv_pw[0][0]']
#
#  block_3_conv_dw (Depthwise  (None, 30, 40, 16)           160       ['add_1[0][0]']
#  Conv2D)
#
#  re_lu_7 (ReLU)              (None, 30, 40, 16)           0         ['block_3_conv_dw[0][0]']
#
#  block_3_conv_pw (Conv2D)    (None, 30, 40, 8)            136       ['re_lu_7[0][0]']
#
#  add_2 (Add)                 (None, 30, 40, 8)            0         ['add_1[0][0]',
#                                                                      'block_3_conv_pw[0][0]']
#
#  Conv2D_layer6 (Conv2D)      (None, 30, 40, 16)           144       ['add_2[0][0]']
#
#  re_lu_8 (ReLU)              (None, 30, 40, 16)           0         ['Conv2D_layer6[0][0]']
#
#  DepthWiseConv2D_layer7 (De  (None, 30, 40, 16)           160       ['re_lu_8[0][0]']
#  pthwiseConv2D)
#
#  re_lu_9 (ReLU)              (None, 30, 40, 16)           0         ['DepthWiseConv2D_layer7[0][0]
#                                                                     ']
#
#  Conv2D_layer8 (Conv2D)      (None, 30, 40, 16)           272       ['re_lu_9[0][0]']
#
#  re_lu_10 (ReLU)             (None, 30, 40, 16)           0         ['Conv2D_layer8[0][0]']
#
#  DepthWiseConv2D_layer9 (De  (None, 15, 20, 32)           320       ['re_lu_10[0][0]']
#  pthwiseConv2D)
#
#  re_lu_11 (ReLU)             (None, 15, 20, 32)           0         ['DepthWiseConv2D_layer9[0][0]
#                                                                     ']
#
#  Conv2D_layer10 (Conv2D)     (None, 15, 20, 24)           792       ['re_lu_11[0][0]']
#
#  re_lu_12 (ReLU)             (None, 15, 20, 24)           0         ['Conv2D_layer10[0][0]']
#
#  block_4_conv_dw (Depthwise  (None, 15, 20, 48)           480       ['re_lu_12[0][0]']
#  Conv2D)
#
#  re_lu_13 (ReLU)             (None, 15, 20, 48)           0         ['block_4_conv_dw[0][0]']
#
#  block_4_conv_pw (Conv2D)    (None, 15, 20, 24)           1176      ['re_lu_13[0][0]']
#
#  add_3 (Add)                 (None, 15, 20, 24)           0         ['re_lu_12[0][0]',
#                                                                      'block_4_conv_pw[0][0]']
#
#  block_5_conv_dw (Depthwise  (None, 15, 20, 48)           480       ['add_3[0][0]']
#  Conv2D)
#
#  re_lu_14 (ReLU)             (None, 15, 20, 48)           0         ['block_5_conv_dw[0][0]']
#
#  block_5_conv_pw (Conv2D)    (None, 15, 20, 24)           1176      ['re_lu_14[0][0]']
#
#  add_4 (Add)                 (None, 15, 20, 24)           0         ['add_3[0][0]',
#                                                                      'block_5_conv_pw[0][0]']
#
#  block_6_conv_dw (Depthwise  (None, 15, 20, 48)           480       ['add_4[0][0]']
#  Conv2D)
#
#  re_lu_15 (ReLU)             (None, 15, 20, 48)           0         ['block_6_conv_dw[0][0]']
#
#  block_6_conv_pw (Conv2D)    (None, 15, 20, 24)           1176      ['re_lu_15[0][0]']
#
#  add_5 (Add)                 (None, 15, 20, 24)           0         ['add_4[0][0]',
#                                                                      'block_6_conv_pw[0][0]']
#
#  Conv2D_layer11 (Conv2D)     (None, 15, 20, 48)           1200      ['add_5[0][0]']
#
#  re_lu_16 (ReLU)             (None, 15, 20, 48)           0         ['Conv2D_layer11[0][0]']
#
#  DepthWiseConv2D_layer12 (D  (None, 15, 20, 48)           480       ['re_lu_16[0][0]']
#  epthwiseConv2D)
#
#  re_lu_17 (ReLU)             (None, 15, 20, 48)           0         ['DepthWiseConv2D_layer12[0][0
#                                                                     ]']
#
#  Conv2D_layer13 (Conv2D)     (None, 15, 20, 64)           3136      ['re_lu_17[0][0]']
#
#  re_lu_18 (ReLU)             (None, 15, 20, 64)           0         ['Conv2D_layer13[0][0]']
#
#  DepthWiseConv2D_layer14 (D  (None, 15, 20, 64)           640       ['re_lu_18[0][0]']
#  epthwiseConv2D)
#
#  re_lu_19 (ReLU)             (None, 15, 20, 64)           0         ['DepthWiseConv2D_layer14[0][0
#                                                                     ]']
#
#  Conv2D_layer15 (Conv2D)     (None, 8, 10, 40)            2600      ['re_lu_19[0][0]']
#
#  re_lu_20 (ReLU)             (None, 8, 10, 40)            0         ['Conv2D_layer15[0][0]']
#
#  block_7_conv_dw (Depthwise  (None, 8, 10, 80)            800       ['re_lu_20[0][0]']
#  Conv2D)
#
#  re_lu_21 (ReLU)             (None, 8, 10, 80)            0         ['block_7_conv_dw[0][0]']
#
#  block_7_conv_pw (Conv2D)    (None, 8, 10, 40)            3240      ['re_lu_21[0][0]']
#
#  add_6 (Add)                 (None, 8, 10, 40)            0         ['re_lu_20[0][0]',
#                                                                      'block_7_conv_pw[0][0]']
#
#  block_8_conv_dw (Depthwise  (None, 8, 10, 80)            800       ['add_6[0][0]']
#  Conv2D)
#
#  re_lu_22 (ReLU)             (None, 8, 10, 80)            0         ['block_8_conv_dw[0][0]']
#
#  block_8_conv_pw (Conv2D)    (None, 8, 10, 40)            3240      ['re_lu_22[0][0]']
#
#  add_7 (Add)                 (None, 8, 10, 40)            0         ['add_6[0][0]',
#                                                                      'block_8_conv_pw[0][0]']
#
#  Conv2D_layer16 (Conv2D)     (None, 8, 10, 80)            3280      ['add_7[0][0]']
#
#  re_lu_23 (ReLU)             (None, 8, 10, 80)            0         ['Conv2D_layer16[0][0]']
#
#  DepthWiseConv2D_layer17 (D  (None, 8, 10, 80)            800       ['re_lu_23[0][0]']
#  epthwiseConv2D)
#
#  re_lu_24 (ReLU)             (None, 8, 10, 80)            0         ['DepthWiseConv2D_layer17[0][0
#                                                                     ]']
#
#  Conv2D_layer18 (Conv2D)     (None, 8, 10, 80)            6480      ['re_lu_24[0][0]']
#
#  re_lu_25 (ReLU)             (None, 8, 10, 80)            0         ['Conv2D_layer18[0][0]']
#
#  DepthWiseConv2D_layer19 (D  (None, 4, 5, 80)             800       ['re_lu_25[0][0]']
#  epthwiseConv2D)
#
#  re_lu_26 (ReLU)             (None, 4, 5, 80)             0         ['DepthWiseConv2D_layer19[0][0
#                                                                     ]']
#
#  Conv2D_layer20 (Conv2D)     (None, 4, 5, 80)             6480      ['re_lu_26[0][0]']
#
#  re_lu_27 (ReLU)             (None, 4, 5, 80)             0         ['Conv2D_layer20[0][0]']
#
#  DepthWiseConv2D_layer21 (D  (None, 2, 3, 80)             800       ['re_lu_27[0][0]']
#  epthwiseConv2D)
#
#  re_lu_28 (ReLU)             (None, 2, 3, 80)             0         ['DepthWiseConv2D_layer21[0][0
#                                                                     ]']
#
#  Conv2D_layer22 (Conv2D)     (None, 2, 3, 64)             5184      ['re_lu_28[0][0]']
#
#  re_lu_29 (ReLU)             (None, 2, 3, 64)             0         ['Conv2D_layer22[0][0]']
#
#  DepthWiseConv2D_layer23 (D  (None, 1, 1, 64)             640       ['re_lu_29[0][0]']
#  epthwiseConv2D)
#
#  re_lu_30 (ReLU)             (None, 1, 1, 64)             0         ['DepthWiseConv2D_layer23[0][0
#                                                                     ]']
#
#  Conv2D_layer24 (Conv2D)     (None, 1, 1, 64)             4160      ['re_lu_30[0][0]']
#
#  re_lu_31 (ReLU)             (None, 1, 1, 64)             0         ['Conv2D_layer24[0][0]']
#
#  DepthwiseConv2D_loc_DD1_1   (None, 15, 20, 64)           640       ['re_lu_18[0][0]']
#  (DepthwiseConv2D)
#
#  DepthwiseConv2D_loc_DD2_1   (None, 8, 10, 80)            800       ['re_lu_25[0][0]']
#  (DepthwiseConv2D)
#
#  DepthwiseConv2D_loc_DD3_1   (None, 4, 5, 80)             800       ['re_lu_27[0][0]']
#  (DepthwiseConv2D)
#
#  DepthwiseConv2D_loc_DD4_1   (None, 2, 3, 64)             640       ['re_lu_29[0][0]']
#  (DepthwiseConv2D)
#
#  DepthwiseConv2D_loc_DD5_1   (None, 1, 1, 64)             640       ['re_lu_31[0][0]']
#  (DepthwiseConv2D)
#
#  DepthwiseConv2D_conf_DD1_1  (None, 15, 20, 64)           640       ['re_lu_18[0][0]']
#   (DepthwiseConv2D)
#
#  DepthwiseConv2D_conf_DD2_1  (None, 8, 10, 80)            800       ['re_lu_25[0][0]']
#   (DepthwiseConv2D)
#
#  DepthwiseConv2D_conf_DD3_1  (None, 4, 5, 80)             800       ['re_lu_27[0][0]']
#   (DepthwiseConv2D)
#
#  DepthwiseConv2D_conf_DD4_1  (None, 2, 3, 64)             640       ['re_lu_29[0][0]']
#   (DepthwiseConv2D)
#
#  DepthwiseConv2D_conf_DD5_1  (None, 1, 1, 64)             640       ['re_lu_31[0][0]']
#   (DepthwiseConv2D)
#
#  re_lu_33 (ReLU)             (None, 15, 20, 64)           0         ['DepthwiseConv2D_loc_DD1_1[0]
#                                                                     [0]']
#
#  re_lu_35 (ReLU)             (None, 8, 10, 80)            0         ['DepthwiseConv2D_loc_DD2_1[0]
#                                                                     [0]']
#
#  re_lu_37 (ReLU)             (None, 4, 5, 80)             0         ['DepthwiseConv2D_loc_DD3_1[0]
#                                                                     [0]']
#
#  re_lu_39 (ReLU)             (None, 2, 3, 64)             0         ['DepthwiseConv2D_loc_DD4_1[0]
#                                                                     [0]']
#
#  re_lu_41 (ReLU)             (None, 1, 1, 64)             0         ['DepthwiseConv2D_loc_DD5_1[0]
#                                                                     [0]']
#
#  re_lu_32 (ReLU)             (None, 15, 20, 64)           0         ['DepthwiseConv2D_conf_DD1_1[0
#                                                                     ][0]']
#
#  re_lu_34 (ReLU)             (None, 8, 10, 80)            0         ['DepthwiseConv2D_conf_DD2_1[0
#                                                                     ][0]']
#
#  re_lu_36 (ReLU)             (None, 4, 5, 80)             0         ['DepthwiseConv2D_conf_DD3_1[0
#                                                                     ][0]']
#
#  re_lu_38 (ReLU)             (None, 2, 3, 64)             0         ['DepthwiseConv2D_conf_DD4_1[0
#                                                                     ][0]']
#
#  re_lu_40 (ReLU)             (None, 1, 1, 64)             0         ['DepthwiseConv2D_conf_DD5_1[0
#                                                                     ][0]']
#
#  Conv2D_loc_DD1_2 (Conv2D)   (None, 15, 20, 8)            520       ['re_lu_33[0][0]']
#
#  Conv2D_loc_DD2_2 (Conv2D)   (None, 8, 10, 24)            1944      ['re_lu_35[0][0]']
#
#  Conv2D_loc_DD3_2 (Conv2D)   (None, 4, 5, 24)             1944      ['re_lu_37[0][0]']
#
#  Conv2D_loc_DD4_2 (Conv2D)   (None, 2, 3, 24)             1560      ['re_lu_39[0][0]']
#
#  Conv2D_loc_DD5_2 (Conv2D)   (None, 1, 1, 24)             1560      ['re_lu_41[0][0]']
#
#  Conv2D_conf_DD1_2 (Conv2D)  (None, 15, 20, 6)            390       ['re_lu_32[0][0]']
#
#  Conv2D_conf_DD2_2 (Conv2D)  (None, 8, 10, 18)            1458      ['re_lu_34[0][0]']
#
#  Conv2D_conf_DD3_2 (Conv2D)  (None, 4, 5, 18)             1458      ['re_lu_36[0][0]']
#
#  Conv2D_conf_DD4_2 (Conv2D)  (None, 2, 3, 18)             1170      ['re_lu_38[0][0]']
#
#  Conv2D_conf_DD5_2 (Conv2D)  (None, 1, 1, 18)             1170      ['re_lu_40[0][0]']
#
#  reshape_1 (Reshape)         (None, 600, 4)               0         ['Conv2D_loc_DD1_2[0][0]']
#
#  reshape_3 (Reshape)         (None, 480, 4)               0         ['Conv2D_loc_DD2_2[0][0]']
#
#  reshape_5 (Reshape)         (None, 120, 4)               0         ['Conv2D_loc_DD3_2[0][0]']
#
#  reshape_7 (Reshape)         (None, 36, 4)                0         ['Conv2D_loc_DD4_2[0][0]']
#
#  reshape_9 (Reshape)         (None, 6, 4)                 0         ['Conv2D_loc_DD5_2[0][0]']
#
#  reshape (Reshape)           (None, 600, 3)               0         ['Conv2D_conf_DD1_2[0][0]']
#
#  reshape_2 (Reshape)         (None, 480, 3)               0         ['Conv2D_conf_DD2_2[0][0]']
#
#  reshape_4 (Reshape)         (None, 120, 3)               0         ['Conv2D_conf_DD3_2[0][0]']
#
#  reshape_6 (Reshape)         (None, 36, 3)                0         ['Conv2D_conf_DD4_2[0][0]']
#
#  reshape_8 (Reshape)         (None, 6, 3)                 0         ['Conv2D_conf_DD5_2[0][0]']
#
#  mbox_loc (Concatenate)      (None, 1242, 4)              0         ['reshape_1[0][0]',
#                                                                      'reshape_3[0][0]',
#                                                                      'reshape_5[0][0]',
#                                                                      'reshape_7[0][0]',
#                                                                      'reshape_9[0][0]']
#
#  mbox_conf (Concatenate)     (None, 1242, 3)              0         ['reshape[0][0]',
#                                                                      'reshape_2[0][0]',
#                                                                      'reshape_4[0][0]',
#                                                                      'reshape_6[0][0]',
#                                                                      'reshape_8[0][0]']
#
#  mbox_loc_final (Reshape)    (None, 1242, 4)              0         ['mbox_loc[0][0]']
#
#  cls_conf_final (Activation  (None, 1242, 3)              0         ['mbox_conf[0][0]']
#  )
#
#  predictions (Concatenate)   (None, 1242, 7)              0         ['mbox_loc_final[0][0]',
#                                                                      'cls_conf_final[0][0]']
#
# ==================================================================================================
# Total params: 73046 (285.34 KB)
# Trainable params: 73046 (285.34 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
